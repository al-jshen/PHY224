# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
dat = np.loadtxt('data.csv', skiprows=1, delimiter=',')

# %%
data = pd.read_csv('data.csv')

# %%
data['resistance'] = data.current*1000 / data.voltage

# %%
plt.scatter(x=data.current, y=data.voltage, c=data.resistance)

# %%
plt.scatter(x=dat[:,0], y=dat[:,1], c=dat[:,2])
